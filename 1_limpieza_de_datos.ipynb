# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)
#
# # Limpieza de datos para crear gráficos descriptivos y modelo de ML
#
# Nos dan un dataset con información relativa da distintas películas y el número de likes que han recibido en Facebook y Twitter. Nos piden:
#
# 1. Preparar el dataset para crear un modelo de ML que nos permita predecir el número de likes a partir de las características de las películas.
# 2. Además del modelo, necesitaremos presentar algunos gráficos a nuestros stakeholders. Es necesario que la data este preparada para ello.
# 3. Identificar problemas graves en la data y comunicarlos lo antes posible.
# 4. Adicionalmente, nuestro stakeholder tiene "curiosidad" por algunas cifras:
#     - Actores más repetidos en el dataset
#     - Géneros de películas más comunes
#     - Relación entre presupuesto y recaudación

# %%
import pandas as pd
import numpy as np

# %%
#??pd.read_csv

# %%
df = pd.read_csv("data/imdb_clase.csv", sep=';', index_col= 0).reset_index(drop = True)#index 0 porque la columna 0 es el indice ,si tenemos una columna unnamed, y no la queremos porque el programa la refleja como una cosa rara

# %% [markdown]
# ## Leer datos

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# ### Revisiones generales: `.columns`, `.index`, `.shape`

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'duration', 'gross', 'genres', 'movie_title',
#        'title_year', 'language', 'country', 'budget', 'imdb_score', 'actors',
#        'movie_facebook_likes', 'movie_twitter_likes'],
#       dtype='object')

# %%
df.describe(include='all').T#nos fimjamos en los negativos del min, el include incluye no solo las numericas, sino tambien las categoricas. Nan es valor vacio
# Out:
#                      count unique  \
# color                   88      3
# director_name           88     63
# duration              99.0    NaN
# gross                   99     87
# genres                  98     56
# movie_title             99     91
# title_year            99.0    NaN
# language                99      1
# country                 99     12
# budget                  99     57
# imdb_score            99.0    NaN
# actors                  99     88
# movie_facebook_likes  99.0    NaN
# movie_twitter_likes   99.0    NaN
#
#                                                                     top freq  \
# color                                                             Color   86
# director_name                                              Ridley Scott    4
# duration                                                            NaN  NaN
# gross                                                              $nan    7
# genres                                          Action|Adventure|Sci-Fi   10
# movie_title                                                     ben-hur    3
# title_year                                                          NaN  NaN
# language                                                        English   99
# country                                                             USA   77
# budget                                               USD 100,000,000.00    6
# imdb_score                                                          NaN  NaN
# actors                Chris Hemsworth,Robert Downey Jr.,Scarlett Joh...    3
# movie_facebook_likes                                                NaN  NaN
# movie_twitter_likes                                                 NaN  NaN
#
#                               mean           std     min      25%      50%  \
# color                          NaN           NaN     NaN      NaN      NaN
# director_name                  NaN           NaN     NaN      NaN      NaN
# duration                155.494949     72.797927   -50.0    138.5    143.0
# gross                          NaN           NaN     NaN      NaN      NaN
# genres                         NaN           NaN     NaN      NaN      NaN
# movie_title                    NaN           NaN     NaN      NaN      NaN
# title_year             1944.010101    393.848787 -1000.0   2012.0   2013.0
# language                       NaN           NaN     NaN      NaN      NaN
# country                        NaN           NaN     NaN      NaN      NaN
# budget                         NaN           NaN     NaN      NaN      NaN
# imdb_score                6.892929      1.925514    -7.5     6.55      7.2
# actors                         NaN           NaN     NaN      NaN      NaN
# movie_facebook_likes  66045.707071  58108.860365     0.0  25000.0  54000.0
# movie_twitter_likes         1000.0           0.0  1000.0   1000.0   1000.0
#
#                           75%       max
# color                     NaN       NaN
# director_name             NaN       NaN
# duration                155.0     650.0
# gross                     NaN       NaN
# genres                    NaN       NaN
# movie_title               NaN       NaN
# title_year             2014.0    2030.0
# language                  NaN       NaN
# country                   NaN       NaN
# budget                    NaN       NaN
# imdb_score               7.85       8.8
# actors                    NaN       NaN
# movie_facebook_likes  85500.0  349000.0
# movie_twitter_likes    1000.0    1000.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=99, step=1)

# %%
df.shape
# Out:
# (99, 14)

# %% [markdown]
# ### Ver algunas observaciones: `.head()`, `.tail()`, `.sample()`

# %%
#df.head().T Si ponemos .T lo trasponemos
df.head()
# Out:
#     color      director_name  duration            gross  \
# 0   Color    Martin Scorsese       240  $116,866,727.00
# 1   Color        Shane Black       195  $408,992,272.00
# 2  color   Quentin Tarantino       187   $54,116,191.00
# 3   Color   Kenneth Lonergan       186       $46,495.00
# 4   Color      Peter Jackson       186  $258,355,354.00
#
#                                  genres                          movie_title  \
# 0          Biography|Comedy|Crime|Drama              the wolf of wall street
# 1               Action|Adventure|Sci-Fi                           iron man 3
# 2  Crime|Drama|Mystery|Thriller|Western                    the hateful eight
# 3                                 Drama                             margaret
# 4                     Adventure|Fantasy  the hobbit: the desolation of smaug
#
#    title_year language country              budget  imdb_score  \
# 0        2013  English     USA  USD 100,000,000.00         8.2
# 1        2013  English     USA  USD 200,000,000.00         7.2
# 2        2015  English     USA   USD 44,000,000.00         7.9
# 3        2011  English     usa   USD 14,000,000.00         6.5
# 4        2013  English     USA  USD 225,000,000.00         7.9
#
#                                               actors  movie_facebook_likes  \
# 0  Leonardo DiCaprio,Matthew McConaughey,Jon Favreau                138000
# 1          Robert Downey Jr.,Jon Favreau,Don Cheadle                 95000
# 2          Craig Stark,Jennifer Jason Leigh,Zoë Bell                114000
# 3        Matt Damon,Kieran Culkin,John Gallagher Jr.                     0
# 4              Aidan Turner,Adam Brown,James Nesbitt                 83000
#
#    movie_twitter_likes
# 0                 1000
# 1                 1000
# 2                 1000
# 3                 1000
# 4                 1000

# %%
df.sample(5)
# Out:
#     color     director_name  duration            gross                genres  \
# 43  Color       Tate Taylor       146  $169,705,587.00                 Drama
# 3   Color  Kenneth Lonergan       186       $46,495.00                 Drama
# 79  Color      Ridley Scott       138   $16,969,390.00  Crime|Drama|Thriller
# 65    NaN      Oliver Stone       141   $47,307,550.00  Crime|Drama|Thriller
# 4   Color     Peter Jackson       186  $258,355,354.00     Adventure|Fantasy
#
#                             movie_title  title_year language country  \
# 43                             the help        2011  English     USA
# 3                              margaret        2011  English     usa
# 79                        the counselor        2013  English     USA
# 65                              savages        2012  English     USA
# 4   the hobbit: the desolation of smaug        2013  English     USA
#
#                 budget  imdb_score  \
# 43   USD 25,000,000.00         8.1
# 3    USD 14,000,000.00         6.5
# 79   USD 25,000,000.00         5.3
# 65   USD 45,000,000.00         6.5
# 4   USD 225,000,000.00         7.9
#
#                                          actors  movie_facebook_likes  \
# 43    Emma Stone,Bryce Dallas Howard,Mike Vogel                 75000
# 3   Matt Damon,Kieran Culkin,John Gallagher Jr.                     0
# 79   Michael Fassbender,Brad Pitt,Goran Visnjic                 24000
# 65      Demián Bichir,Shea Whigham,Gary Stretch                 28000
# 4         Aidan Turner,Adam Brown,James Nesbitt                 83000
#
#     movie_twitter_likes
# 43                 1000
# 3                  1000
# 79                 1000
# 65                 1000
# 4                  1000

# %% [markdown]
# ### Describir dataset: `info()`, `describe()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   color                 88 non-null     object
#  1   director_name         88 non-null     object
#  2   duration              99 non-null     int64
#  3   gross                 99 non-null     object
#  4   genres                98 non-null     object
#  5   movie_title           99 non-null     object
#  6   title_year            99 non-null     int64
#  7   language              99 non-null     object
#  8   country               99 non-null     object
#  9   budget                99 non-null     object
#  10  imdb_score            99 non-null     float64
#  11  actors                99 non-null     object
#  12  movie_facebook_likes  99 non-null     int64
#  13  movie_twitter_likes   99 non-null     int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 11.0+ KB

# %% [markdown]
# ### Valores faltantes: `.isnull()`, `.isna()`

# %%
df.isnull().any()#con any va columna a columna diciendo si hay algun null, y si es asi te pone true
# Out:
# color                    True
# director_name            True
# duration                False
# gross                   False
# genres                   True
# movie_title             False
# title_year              False
# language                False
# country                 False
# budget                  False
# imdb_score              False
# actors                  False
# movie_facebook_likes    False
# movie_twitter_likes     False
# dtype: bool

# %%
df.isna().sum()#los na en cada columna
# Out:
# color                   11
# director_name           11
# duration                 0
# gross                    0
# genres                   1
# movie_title              0
# title_year               0
# language                 0
# country                  0
# budget                   0
# imdb_score               0
# actors                   0
# movie_facebook_likes     0
# movie_twitter_likes      0
# dtype: int64

# %%
df.isna().mean()*100#en porcentaje
# Out:
# color                   11.111111
# director_name           11.111111
# duration                 0.000000
# gross                    0.000000
# genres                   1.010101
# movie_title              0.000000
# title_year               0.000000
# language                 0.000000
# country                  0.000000
# budget                   0.000000
# imdb_score               0.000000
# actors                   0.000000
# movie_facebook_likes     0.000000
# movie_twitter_likes      0.000000
# dtype: float64

# %%
df[df.duplicated(keep = False)]#filas duplicadas, y el keep false, lo que hace es te saca las filas duplicadas de arriba abajo
# Out:
#     color      director_name  duration            gross  \
# 8   Color        Joss Whedon       173  $623,279,547.00
# 9   Color        Joss Whedon       173  $623,279,547.00
# 30  Color       Ridley Scott       150   $65,007,045.00
# 31  Color       Ridley Scott       150   $65,007,045.00
# 52  Color         Sam Mendes       143  $304,360,277.00
# 53  Color         Sam Mendes       143  $304,360,277.00
# 54  Color       Baz Luhrmann       143  $144,812,796.00
# 55  Color       Baz Luhrmann       143  $144,812,796.00
# 61  Color  Timur Bekmambetov       141             $nan
# 63  Color  Timur Bekmambetov       141             $nan
#
#                        genres             movie_title  title_year language  \
# 8     Action|Adventure|Sci-Fi            the avengers        2012  English
# 9     Action|Adventure|Sci-Fi            the avengers        2012  English
# 30     Action|Adventure|Drama  exodus: gods and kings        2014  English
# 31     Action|Adventure|Drama  exodus: gods and kings        2014  English
# 52  Action|Adventure|Thriller                 skyfall        2012  English
# 53  Action|Adventure|Thriller                 skyfall        2012  English
# 54              Drama|Romance        the great gatsby        2013  English
# 55              Drama|Romance        the great gatsby        2013  English
# 61    Adventure|Drama|History                 ben-hur        2016  English
# 63    Adventure|Drama|History                 ben-hur        2016  English
#
#       country              budget  imdb_score  \
# 8         USA  USD 220,000,000.00         8.1
# 9         USA  USD 220,000,000.00         8.1
# 30         UK  USD 140,000,000.00         6.1
# 31         UK  USD 140,000,000.00         6.1
# 52         UK  USD 200,000,000.00         7.8
# 53         UK  USD 200,000,000.00         7.8
# 54  Australia  USD 105,000,000.00         7.3
# 55  Australia  USD 105,000,000.00         7.3
# 61        USA  USD 100,000,000.00         6.1
# 63        USA  USD 100,000,000.00         6.1
#
#                                                actors  movie_facebook_likes  \
# 8   Chris Hemsworth,Robert Downey Jr.,Scarlett Joh...                123000
# 9   Chris Hemsworth,Robert Downey Jr.,Scarlett Joh...                123000
# 30       Christian Bale,María Valverde,Ben Mendelsohn                 51000
# 31       Christian Bale,María Valverde,Ben Mendelsohn                 51000
# 52           Albert Finney,Helen McCrory,Rory Kinnear                 80000
# 53           Albert Finney,Helen McCrory,Rory Kinnear                 80000
# 54   Leonardo DiCaprio,Elizabeth Debicki,Steve Bisley                115000
# 55   Leonardo DiCaprio,Elizabeth Debicki,Steve Bisley                115000
# 61           Morgan Freeman,Ayelet Zurer,Moises Arias                     0
# 63           Morgan Freeman,Ayelet Zurer,Moises Arias                     0
#
#     movie_twitter_likes
# 8                  1000
# 9                  1000
# 30                 1000
# 31                 1000
# 52                 1000
# 53                 1000
# 54                 1000
# 55                 1000
# 61                 1000
# 63                 1000

# %%
df.duplicated().value_counts()
# Out:
# False    94
# True      5
# dtype: int64

# %%
df.shape, df.drop_duplicates().shape
# Out:
# ((99, 14), (94, 14))

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Quitar filas duplicadas: `.duplicated()`. `.drop_duplicates()`

# %% [markdown]
# ## Tratamiento de columnas
#
# Dylan:
#
# - `color`
# - `director_name`
# - `gross`
# - `duration`
#
# Todos:
# - `movie_title`
# - `title_year`
# - `movie_twitter_likes`
# - `imdb_score`
# - `country`
# - `language`
# - `actors`
# - `movie_facebook_likes`

# %% [markdown]
# ### Columna `color`

# %%
df['color'].value_counts()#si volvemos al df.shape vemos que hay 94 filas, para que nos enseñe los nulos, celda de abajo
# Out:
# Color               81
# color                1
#  Black and White     1
# Name: color, dtype: int64

# %%
df['color'].value_counts(dropna=False)
# Out:
# Color               81
# NaN                 11
# color                1
#  Black and White     1
# Name: color, dtype: int64

# %%
df[df['color'].isna()].T
# Out:
#                                                             5   \
# color                                                      NaN
# director_name                                              NaN
# duration                                                   183
# gross                                          $330,249,062.00
# genres                                 Action|Adventure|Sci-Fi
# movie_title                 batman v superman: dawn of justice
# title_year                                                 202
# language                                               English
# country                                                    USA
# budget                                      USD 250,000,000.00
# imdb_score                                                 6.9
# actors                Henry Cavill,Lauren Cohan,Alan D. Purwin
# movie_facebook_likes                                    197000
# movie_twitter_likes                                       1000
#
#                                                         10  \
# color                                                  NaN
# director_name                                   Tom Tykwer
# duration                                               172
# gross                                       $27,098,580.00
# genres                                        Drama|Sci-Fi
# movie_title                                    cloud atlas
# title_year                                            2012
# language                                           English
# country                                            Germany
# budget                                  USD 102,000,000.00
# imdb_score                                            -7.5
# actors                Tom Hanks,Jim Sturgess,Jim Broadbent
# movie_facebook_likes                                124000
# movie_twitter_likes                                   1000
#
#                                                                   15  \
# color                                                            NaN
# director_name                                      Richard Linklater
# duration                                                         165
# gross                                                 $25,359,200.00
# genres                                                         Drama
# movie_title                                                  boyhood
# title_year                                                      2014
# language                                                     English
# country                                                          USA
# budget                                              USD 4,000,000.00
# imdb_score                                                       8.0
# actors                Ellar Coltrane,Lorelei Linklater,Libby Villari
# movie_facebook_likes                                           92000
# movie_twitter_likes                                             1000
#
#                                                                  18  \
# color                                                           NaN
# director_name                                     Christopher Nolan
# duration                                                        164
# gross                                               $448,130,642.00
# genres                                              Action|Thriller
# movie_title                                   the dark knight rises
# title_year                                                     2012
# language                                                    English
# country                                                         USA
# budget                                           USD 250,000,000.00
# imdb_score                                                      8.5
# actors                Tom Hardy,Christian Bale,Joseph Gordon-Levitt
# movie_facebook_likes                                         164000
# movie_twitter_likes                                            1000
#
#                                                                  56  \
# color                                                           NaN
# director_name                                                   NaN
# duration                                                        143
# gross                                                          $nan
# genres                                        Drama|Horror|Thriller
# movie_title                                              the ridges
# title_year                                                     2011
# language                                                    English
# country                                                         USA
# budget                                                USD 17,350.00
# imdb_score                                                      3.0
# actors                Robbie Barnes,Alana Kaniewski,Brandon Landers
# movie_facebook_likes                                             33
# movie_twitter_likes                                            1000
#
#                                                            65  \
# color                                                     NaN
# director_name                                    Oliver Stone
# duration                                                  141
# gross                                          $47,307,550.00
# genres                                   Crime|Drama|Thriller
# movie_title                                           savages
# title_year                                               2012
# language                                              English
# country                                                   USA
# budget                                      USD 45,000,000.00
# imdb_score                                                6.5
# actors                Demián Bichir,Shea Whigham,Gary Stretch
# movie_facebook_likes                                    28000
# movie_twitter_likes                                      1000
#
#                                                      74  \
# color                                               NaN
# director_name                           Terrence Malick
# duration                                            139
# gross                                    $13,303,319.00
# genres                                    Drama|Fantasy
# movie_title                            the tree of life
# title_year                                         2011
# language                                        English
# country                                             USA
# budget                                USD 32,000,000.00
# imdb_score                                          6.7
# actors                Brad Pitt,Tye Sheridan,Fiona Shaw
# movie_facebook_likes                              39000
# movie_twitter_likes                                1000
#
#                                                                      76  \
# color                                                               NaN
# director_name                                           Robert Zemeckis
# duration                                                            138
# gross                                                    $93,749,203.00
# genres                                                   Drama|Thriller
# movie_title                                                      flight
# title_year                                                         2012
# language                                                        English
# country                                                             USA
# budget                                                USD 31,000,000.00
# imdb_score                                                          7.3
# actors                Denzel Washington,Bruce Greenwood,Nadine Velaz...
# movie_facebook_likes                                              64000
# movie_twitter_likes                                                1000
#
#                                                            80  \
# color                                                     NaN
# director_name                                   James Mangold
# duration                                                  138
# gross                                         $132,550,960.00
# genres                       Action|Adventure|Sci-Fi|Thriller
# movie_title                                     the wolverine
# title_year                                               2013
# language                                              English
# country                                                   USA
# budget                                     USD 120,000,000.00
# imdb_score                                                6.7
# actors                Hugh Jackman,Tao Okamoto,Rila Fukushima
# movie_facebook_likes                                    68000
# movie_twitter_likes                                      1000
#
#                                                                  83  \
# color                                                           NaN
# director_name                                         Walter Salles
# duration                                                        137
# gross                                                   $717,753.00
# genres                                              Adventure|Drama
# movie_title                                             on the road
# title_year                                                     2012
# language                                                    English
# country                                                      France
# budget                                            USD 25,000,000.00
# imdb_score                                                      6.1
# actors                Kristen Stewart,Viggo Mortensen,Kirsten Dunst
# movie_facebook_likes                                          27000
# movie_twitter_likes                                            1000
#
#                                                                87
# color                                                         NaN
# director_name                                     Seth MacFarlane
# duration                                                      136
# gross                                              $42,615,685.00
# genres                                             Comedy|Western
# movie_title                     a million ways to die in the west
# title_year                                                   2014
# language                                                  English
# country                                                       USA
# budget                                          USD 40,000,000.00
# imdb_score                                                    6.1
# actors                Liam Neeson,Charlize Theron,Seth MacFarlane
# movie_facebook_likes                                        24000
# movie_twitter_likes                                          1000

# %%
df.loc[df['color'].isna(),'color'] = 'Color'
df
# Out:
#      color      director_name  duration            gross  \
# 0    Color    Martin Scorsese       240  $116,866,727.00
# 1    Color        Shane Black       195  $408,992,272.00
# 2   color   Quentin Tarantino       187   $54,116,191.00
# 3    Color   Kenneth Lonergan       186       $46,495.00
# 4    Color      Peter Jackson       186  $258,355,354.00
# ..     ...                ...       ...              ...
# 94   Color      Steve McQueen       134   $56,667,870.00
# 95   Color   Richard J. Lewis       134    $7,501,404.00
# 96   Color    Paul Greengrass       134  $107,100,855.00
# 97   Color         David Ayer       134   $85,707,116.00
# 98   Color     Clint Eastwood         5   $47,034,272.00
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              the wolf of wall street
# 1                Action|Adventure|Sci-Fi                           iron man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    the hateful eight
# 3                                  Drama                             margaret
# 4                      Adventure|Fantasy  the hobbit: the desolation of smaug
# ..                                   ...                                  ...
# 94               Biography|Drama|History                     12 years a slave
# 95                          Comedy|Drama                     barney's version
# 96              Biography|Drama|Thriller                     captain phillips
# 97                      Action|Drama|War                                 fury
# 98         Biography|Drama|Music|Musical                          jersey boys
#
#     title_year language country              budget  imdb_score  \
# 0         2013  English     USA  USD 100,000,000.00         8.2
# 1         2013  English     USA  USD 200,000,000.00         7.2
# 2         2015  English     USA   USD 44,000,000.00         7.9
# 3         2011  English     usa   USD 14,000,000.00         6.5
# 4         2013  English     USA  USD 225,000,000.00         7.9
# ..         ...      ...     ...                 ...         ...
# 94        2013  English     USA   USD 20,000,000.00         8.1
# 95        2010  English  Canada             USD nan         7.3
# 96        2013  English     USA   USD 55,000,000.00         7.9
# 97        2014  English     USA   USD 68,000,000.00         7.6
# 98        2014  English     USA   USD 40,000,000.00         6.9
#
#                                                actors  movie_facebook_likes  \
# 0   Leonardo DiCaprio,Matthew McConaughey,Jon Favreau                138000
# 1           Robert Downey Jr.,Jon Favreau,Don Cheadle                 95000
# 2           Craig Stark,Jennifer Jason Leigh,Zoë Bell                114000
# 3         Matt Damon,Kieran Culkin,John Gallagher Jr.                     0
# 4               Aidan Turner,Adam Brown,James Nesbitt                 83000
# ..                                                ...                   ...
# 94       Quvenzhané Wallis,Scoot McNairy,Taran Killam                 83000
# 95                   Mark Addy,Atom Egoyan,Paul Gross                     0
# 96             Tom Hanks,Chris Mulkey,Michael Chernus                 65000
# 97                 Brad Pitt,Logan Lerman,Jim Parrack                 82000
# 98      Johnny Cannizzaro,Steve Schirripa,Scott Vance                 16000
#
#     movie_twitter_likes
# 0                  1000
# 1                  1000
# 2                  1000
# 3                  1000
# 4                  1000
# ..                  ...
# 94                 1000
# 95                 1000
# 96                 1000
# 97                 1000
# 98                 1000
#
# [94 rows x 14 columns]

# %%
df['color'].value_counts()
# Out:
# Color               92
# color                1
#  Black and White     1
# Name: color, dtype: int64

# %%
df['color'].str.capitalize().value_counts()#el black and white, python ha puesto el tabulado en mayuscula
# Out:
# Color               92
# Color                1
#  black and white     1
# Name: color, dtype: int64

# %%
df['color'] = df['color'].str.strip().str.capitalize()#el strip limpia los espacios de delante y de despues y luego pone la primera letra en mayuscula

# %%
#assert si lo que viene despues de assert es True no pasa nada pero si es False, da un error.
assert df['color'].isna().sum() == 0 #aqui le decimos una condicion, si la suma de nan es = 0, pues entonces corre bien, si hubiera algun nulo nos saltaba un error
assert df['color'].unique().tolist() == ['Color','Black and white']

# %% [markdown]
# ### Columna `director_name`

# %%
df['director_name'].isna().mean()
# Out:
# Michael Bay          3
# Peter Jackson        3
# Christopher Nolan    3
# Ridley Scott         3
# Martin Scorsese      2
#                     ..
# Adam McKay           1
# Zack Snyder          1
# Baz Luhrmann         1
# Kenneth Lonergan     1
# Clint Eastwood       1
# Name: director_name, Length: 63, dtype: int64

# %%
pd.set_option('display.max_rows', None)#none es lo que hace que nos muestren todas las columnas

# %%
df['director_name'].value_counts(dropna=False)
# Out:
# NaN                  11
# Michael Bay           3
# Peter Jackson         3
# Christopher Nolan     3
# Ridley Scott          3
#                      ..
# Adam McKay            1
# Zack Snyder           1
# Baz Luhrmann          1
# Kenneth Lonergan      1
# Clint Eastwood        1
# Name: director_name, Length: 64, dtype: int64

# %%
df.loc[df['director_name'].isna(),'director_name'] = 'No informacion'

# %%
assert df['director_name'].isna().sum()==0

# %% [markdown]
# ### Columna `gross`

# %% [markdown]
# ### Columna `genres`

# %% [markdown]
# ### Columna `budget`

# %% [markdown]
# ### Columna `duration`

# %% [markdown]
# ## Guardar dataset

# %% [markdown]
# ### Columna `movie_title`

# %% [markdown]
# ### Columna `title_year`

# %% [markdown]
# ### Columna `movie_twitter_likes`

# %% [markdown]
# ### Columna `imdb_score`

# %% [markdown]
# ### Columna `country`

# %% [markdown]
# ### Columna `language`

# %% [markdown]
# ### Columna `movie_facebook_likes`

# %% [markdown]
# ### Columna `actors`
